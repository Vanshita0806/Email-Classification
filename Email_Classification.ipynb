# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("spam.csv")

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x:1 if x=="spam" else 0)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
def preprocess(text):
    doc = nlp(text)
    filtered_tokens = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        filtered_tokens.append(token.lemma_)
    return " ".join(filtered_tokens)

# %%
df["processed_msg"] = df["Message"].apply(preprocess)

# %%
df.shape
# Out:
# (5572, 4)

# %%
df.head()
# Out:
#   Category                                            Message  spam  \
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0
#
#                                        processed_msg
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win FA Cup final tkts 2...
# 3                                U dun early hor U c
# 4                              nah think go usf live

# %%
df['processed_msg'][0]
# Out:
# 'jurong point crazy available bugis n great world la e buffet cine get amore wat'

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.processed_msg, df.spam, test_size = 0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 5021                            cool little get time soon
# 4082                                      hurry home soup
# 5112    December mobile 11mths+ entitle update late co...
# 127     know yetunde send money send text bother send ...
# Name: processed_msg, dtype: object

# %%
y_train[:4]
# Out:
# 5021    0
# 4082    0
# 5112    1
# 127     0
# Name: spam, dtype: int64

# %%
clf1 = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range = (1,3))),
    ('MultiNB', MultinomialNB())
])

# %%
clf2 = Pipeline([
    ('vectorizer', TfidfVectorizer()),
    ('MultiNB', MultinomialNB())
])

# %%
clf1.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(ngram_range=(1, 3))),
#                 ('MultiNB', MultinomialNB())])

# %%
y_pred1 = clf1.predict(X_test)

# %%
score1 = clf1.score(X_test, y_test)

# %%
print(score1)
# Out:
# 0.9811659192825112

# %%
clf2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', TfidfVectorizer()),
#                 ('MultiNB', MultinomialNB())])

# %%
y_pred2 = clf2.predict(X_test)
score2 = clf2.score(X_test, y_test)
print(score2)
# Out:
# 0.9668161434977578

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf3 = Pipeline([
    ('vectorizer', CountVectorizer(ngram_range = (1,3))),
    ('KNN', KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean'))
])

# %%
clf4 = Pipeline([
    ('vectorizer', TfidfVectorizer()),
    ('KNN', KNeighborsClassifier(n_neighbors = 5, metric = 'euclidean'))
])

# %%
clf3.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(ngram_range=(1, 3))),
#                 ('KNN', KNeighborsClassifier(metric='euclidean'))])

# %%
y_pred3 = clf3.predict(X_test)
score3 = clf3.score(X_test, y_test)
print(score3)
# Out:
# 0.8816143497757848

# %%
clf4.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', TfidfVectorizer()),
#                 ('KNN', KNeighborsClassifier(metric='euclidean'))])

# %%
y_pred4 = clf4.predict(X_test)
score4 = clf4.score(X_test, y_test)
print(score4)
# Out:
# 0.8959641255605382

# %%
df['vector'] = df['processed_msg'].apply(lambda x: nlp(x).vector )

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.head()
# Out:
#   Category                                            Message  spam  \
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0
#
#                                        processed_msg  \
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win FA Cup final tkts 2...
# 3                                U dun early hor U c
# 4                              nah think go usf live
#
#                                               vector
# 0  [1.1192545, 0.980326, 0.26543233, -0.8769394, ...
# 1  [-0.14939333, 1.0167166, 0.4778967, -1.6510634...
# 2  [-0.2184723, -2.4377646, 1.8605095, 0.9640945,...
# 3  [-3.6434948, 3.2535734, 4.5511975, -1.37153, 3...
# 4  [0.04441598, 3.1517997, -3.422078, -0.27837402...

# %%
df['vector'][0].shape
# Out:
# (300,)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(df.vector.values, df.spam, test_size = 0.2, random_state = 22)

# %%
X_train1.shape
# Out:
# (4457,)

# %%
X_train_2d = np.stack(X_train1)

# %%
X_test_2d = np.stack(X_test1)

# %%
X_train1
# Out:
# array([array([-1.522218  , -3.823107  , -2.1704404 , -0.27528667, -0.29322332,
#               -1.2841648 ,  2.2971082 ,  0.21488596,  0.20296057,  0.85559154,
#                0.04110332, -1.969739  , -3.4464972 , -0.38096046, -1.2629168 ,
#               -1.9378579 ,  2.6480806 ,  1.0139581 , -1.0237074 , -0.4054495 ,
#               -0.8187585 , -0.14870428, -1.1310327 ,  2.8060417 ,  0.41730544,
#                1.9699616 , -1.0538626 , -0.48041317, -0.39099902,  0.71153766,
#                1.1770262 ,  1.85609   , -0.11356167, -1.9289862 ,  3.3372762 ,
#                0.6743443 ,  2.7631428 ,  0.27461547, -1.1722784 ,  0.35798144,
#               -0.6186242 ,  1.956289  , -2.0970578 ,  4.199608  , -0.14987756,
#               -0.2617786 ,  0.38411146,  0.88764435,  1.8486418 , -0.67998934,
#                0.8430682 , -1.10015   , -3.442134  , -0.8177819 , -2.6532435 ,
#                1.5034018 , -1.7867792 ,  0.85583586,  0.1139581 , -1.9417485 ,
#                2.3473337 ,  1.8807696 , -0.6466653 , -0.97810525,  1.6613964 ,
#               -0.31723267,  0.24424957,  1.6616371 ,  0.81721014,  0.79825383,
#               -2.8933682 ,  0.53565925,  0.1984887 ,  1.7905986 ,  0.98611516,
#               -1.4680148 ,  0.22208363,  3.4362042 , -2.5919478 ,  3.2625673 ,
#                5.6856155 ,  2.9445338 , -0.8881909 , -2.8659627 , -3.0739844 ,
#               -0.787694  ,  1.3862606 , -1.8975382 ,  2.8505788 ,  3.4509888 ,
#               -0.6545718 , -2.6573577 , -1.5694547 , -0.9459209 , -0.05884302,
#               -5.471518  , -0.34918547,  1.2610805 ,  2.1433551 , -2.1875389 ,
#               -1.3034426 ,  3.36964   ,  5.495161  ,  1.2596024 ,  1.6728976 ,
#                0.91655064,  2.2047942 , -3.2305584 ,  2.1820767 ,  3.8550773 ,
#               -3.2976816 ,  1.9666631 , -4.7397    , -1.6829399 , -2.3907607 ,
#                3.7155046 ,  0.72327226,  0.277106  , -3.0119388 ,  0.13254167,
#               -1.1954428 ,  0.7343504 , -6.375694  , -5.423902  , -1.1018896 ,
#                0.64767027, -1.0246423 ,  2.979269  , -4.6055884 ,  1.0420864 ,
#                1.0214032 ,  0.36075535,  1.8918546 , -0.11924434,  3.5353758 ,
#                2.6187139 ,  0.3747949 , -3.394443  ,  0.21709779, -3.9929185 ,
#               -2.5563965 , -1.1368067 ,  1.84872   ,  0.6677152 ,  0.42138076,
#               -0.18211484,  1.0523988 ,  3.1205688 ,  2.4899004 ,  0.09103518,
#               -0.9771241 ,  0.5049245 ,  0.21478517,  0.36615896, -1.3472534 ,
#               -0.00945538,  4.7052016 , -3.310026  , -1.3529007 ,  0.30811998,
#               -0.00821925,  2.1501882 , -0.31807172, -3.1696684 , -0.87777   ,
#               -1.0044714 , -0.6512517 , -1.6936523 ,  1.0420971 ,  1.4577066 ,
#                1.1987176 , -3.2068198 ,  1.210932  ,  0.55502945, -1.1285006 ,
#               -0.6043366 ,  3.8102682 ,  2.9374707 , -0.08511166,  1.8001337 ,
#               -0.6942394 , -3.0895166 , -3.957729  ,  0.5086536 ,  4.2688975 ,
#               -1.7437861 ,  0.41016033,  1.6973786 ,  0.2695981 , -0.29014635,
#                3.0334897 ,  1.004853  , -0.4388708 ,  0.41385758, -0.69751734,
#                2.7354846 , -1.5407526 ,  0.9297046 ,  0.9250693 , -0.6409591 ,
#               -0.7968348 ,  0.04308783,  0.02366893,  0.95143795,  1.6280571 ,
#               -0.7735285 ,  0.36076975, -2.6362529 ,  1.4538156 , -0.35979944,
#               -0.44058725,  1.7290635 ,  0.9415809 , -1.4884319 , -2.1517406 ,
#                0.5593982 ,  1.5120348 ,  0.5014698 , -0.48703128, -1.2113312 ,
#                4.534033  ,  0.7677805 ,  2.1868742 ,  1.9246538 , -0.41303438,
#               -0.9816674 , -1.7761827 ,  0.7003177 , -0.3014353 ,  0.24349247,
#               -1.6717396 ,  0.27351123, -0.9646817 , -0.4127582 ,  2.0653486 ,
#                0.5741705 ,  0.72628516, -1.4716837 , -1.8088847 ,  0.5984979 ],
#              dtype=float32)                                                    ],
#       dtype=object)

# %%
X_train_2d
# Out:
# array([[-1.522218  , -3.823107  , -2.1704404 , ..., -1.6762636 ,
#         -1.4322667 ,  2.1795278 ],
#        [-1.3528188 , -1.8267708 , -2.094289  , ..., -1.542088  ,
#         -0.19779992,  2.7439222 ],
#        [ 0.40955624,  2.6260335 ,  0.8465111 , ..., -0.66098666,
#          0.20266666,  0.79161114],
#        ...,
#        [ 0.26102787,  0.5486174 , -1.3060302 , ...,  0.627335  ,
#         -1.2749283 ,  0.92560905],
#        [-1.8604    , -1.1013    , -3.9087    , ..., -2.5081    ,
#         -4.5749    , -1.1536    ],
#        [ 0.04626051, -3.3620121 , -0.20317008, ..., -1.4716837 ,
#         -1.8088847 ,  0.5984979 ]], dtype=float32)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaled_train_embed = scaler.fit_transform(X_train_2d)
scaled_test_embed = scaler.transform(X_test_2d)

# %%
clf5 = MultinomialNB()

# %%
clf5.fit(scaled_train_embed, y_train)
# Out:
# MultinomialNB()

# %%
y_pred5 = clf5.predict(scaled_test_embed)

# %%
score5 = clf5.score(scaled_test_embed, y_test)

# %%
print(score5)
# Out:
# 0.8538116591928251

# %%
clf6 = KNeighborsClassifier(n_neighbors = 5, metric ='euclidean')

# %%
clf6.fit(X_train_2d, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred6 = clf6.predict(X_test_2d)

# %%
score6 = clf6.score(X_test_2d, y_test)

# %%
print(score6)
# Out:
# 0.8331838565022421

# %%
from sklearn.metrics import classification_report

# %%
print("CountVectorizer with MultinomialNB\n" , classification_report(y_pred1,y_test))
# Out:
# CountVectorizer with MultinomialNB
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       969
#            1       0.88      0.99      0.93       146
#
#     accuracy                           0.98      1115
#    macro avg       0.94      0.98      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
print("CountVectorizer with KNeighborsClassifier\n" , classification_report(y_pred3,y_test))
# Out:
# CountVectorizer with KNeighborsClassifier
#                precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94      1084
#            1       0.19      1.00      0.32        31
#
#     accuracy                           0.88      1115
#    macro avg       0.60      0.94      0.63      1115
# weighted avg       0.98      0.88      0.92      1115

# %%
print("TfidfVectorizer with KNeighborsClassifier\n" , classification_report(y_pred4,y_test))
# Out:
# TfidfVectorizer with KNeighborsClassifier
#                precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94      1068
#            1       0.29      1.00      0.45        47
#
#     accuracy                           0.90      1115
#    macro avg       0.64      0.95      0.70      1115
# weighted avg       0.97      0.90      0.92      1115

# %%
print("Word Vectors with MultinomialNB\n" , classification_report(y_pred5,y_test))
# Out:
# Word Vectors with MultinomialNB
#                precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92      1115
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.85      1115
#    macro avg       0.50      0.43      0.46      1115
# weighted avg       1.00      0.85      0.92      1115
# C:\Users\Asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("Tfidf with KNeighborsClassifier\n" , classification_report(y_pred1,y_test))
# Out:
# Tfidf with KNeighborsClassifier
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       969
#            1       0.88      0.99      0.93       146
#
#     accuracy                           0.98      1115
#    macro avg       0.94      0.98      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# #### So, our best model from these is (CountVectorizer + MultinomialNB)
